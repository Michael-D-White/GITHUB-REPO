# %% [markdown]
# ### W4A1

# %%
n = int(input())
sum = 0
while n != 0:
    sum += n
    n -= 1
print(sum)
# Out:
# 15

# %% [markdown]
# ### W4A2

# %%
import math
a = 0
while True:
    n = int(input())
    if n > 0:
        a = n
        break
for i in range(2, math.isqrt(a) + 1):
    if a % i == 0:
        print("No")
        break
else:
    print("Yes")
# Out:
# Yes

# %% [markdown]
# ### W4A3

# %%
n = int(input())
ans = 1
while n > 0:
    ans *= n
    n -= 1
print(ans)
# Out:
# 1

# %% [markdown]
# ### W4A4

# %%
n = int(input())
cnt = 1
while n // 10 != 0:
    cnt += 1
    n //= 10
print(cnt)
# Out:
# 5

# %% [markdown]
# ### W4A5

# %%
def solve(n):
    for i in range(n):
        if int(input()) == 42:
            return "I've found the meaning of life!"
    return "It's a joke!"
n = int(input())
solve(n)
# Out:
# "It's a joke!"

# %% [markdown]
# ### W4A6

# %%
import math
a,b = map(int, input().split())
prime = [True] * (b + 1)
prime[0] = prime[1] = False
for i in range(2, math.isqrt(b) + 1):
    if prime[i]:
        for j in range(i**2, b + 1, i):
            prime[j] = False
sum = 0
for i in range(a, b + 1):
    if prime[i]:
        sum += i
print(sum)
# Out:
# 17

# %% [markdown]
# ### W4A7

# %%
import math
n = int(input())
ans = 0
while n % 2 == 0:
    ans = 2
    n //= 2
m = 3
for i in range(m, math.isqrt(n) + 1, 2):
    while n % i == 0:
        ans = i
        n //= i
if n > 2:
    ans = n
print(ans)

# %% [markdown]
# ### W4A8

# %%
def reverse(a):
    b = 0
    while a > 0:
        b = b * 10 + a % 10
        a //= 10
    return b
n = int(input())
step = 0
while n != reverse(n):
    n += reverse(n)
    step += 1
print(step, n)
# Out:
# 1 1441

# %% [markdown]
# ### W4A9

# %%
n = int(input())
i = 1
m = True
while i*i < n:
    ans = i*i
    if len(str(ans)) == len(set(str(ans))):
        print(ans, end = " ")
        m = False
    i += 1
if m == True:
    print("No number")
# Out:
# 1 4 9

# %% [markdown]
# ### W4A10

# %%
def solve(a):
    dic = {1:1}
    def collatz(b):
        if b in dic:
            return dic[b]
        if b % 2 == 0:
            c = b/2
        else:
            c = 3*b + 1
        length = collatz(c) + 1
        dic[b] = length
        return length
    max_collatz = 1
    x = 1
    for i in range(1, n + 1):
        cur = collatz(i)
        if cur > max_collatz:
            max_collatz = cur
            x = i
    return x, max_collatz
n = int(input())
solve(n)
# Out:
# (9, 20)

# %% [markdown]
# ### W4A11

# %%
n = int(input())
cnt = 0
for i in range(2, math.isqrt(n) + 1, 2):
    if n % i == 0:
        cnt += 1
    if (n // i) != i and (n // i) % 2 == 0:
        cnt += 1
print(cnt)
# Out:
# 1

# %% [markdown]
# ### W4A12

# %%
x, n = map(int, input().split())
print(int(x*(1.007**n)))

# %% [markdown]
# ### W4A13

# %%
import math
def dsum(n):
    if n <= 1:
        return 0
    ans = 1
    for i in range(2, math.isqrt(n) + 1):
        if n % i == 0:
            ans += i
            if n /i != i:
                ans += n // i
    return ans
a,b = map(int, input().split())
print(dsum(a) == b and dsum(b) == a)
# Out:
# True

# %% [markdown]
# ### W4A14

# %%
m, n = map(int, input().split())
while n != 0:
    m = n
    n = m % n
print(m)

# %% [markdown]
# ### W4A15

# %%
cnt, leg = map(int, input().split())
dog = (leg - cnt*2)/2
chick = cnt - dog
if dog != int(dog) or dog < 0 or chick < 0:
    print("invalid")
else:
    print(chick, dog)
