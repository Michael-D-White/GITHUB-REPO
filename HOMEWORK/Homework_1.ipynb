# %% [markdown]
# ### 1

# %%
print(2*int(input()))

# %% [markdown]
# ### 2

# %%
a,b = map(int, input().split())
print(f'{(a*b-3.14*b*b):.2f}')

# %% [markdown]
# ### 3

# %%
c = input()
if c.isupper():
    print(c.lower())
else:
    print(c.upper())
# Out:
# a

# %% [markdown]
# ### 4

# %%
c = input()
if c.isalpha():
    print(f"{c} là kí tự alphabet")
else:
    print(f"{c} không phải là kí tự alphabet")

# %% [markdown]
# ### 5

# %%
a = input()
if a == 'A':
    print("Không tồn tại")
else:
    print(chr(ord(a.lower())+1))
# Out:
# c

# %% [markdown]
# ### 6

# %%
a,b,c = map(int, input().split())
if a + b > c and a + c > b and b + c > a:
    p = (a + b + c) / 2
    print(f"{(p*(p-a)*(p-b)*(p-c))**0.5:.1f}")
else:
    print("Không phải 3 cạnh của tam giác")
# Out:
# 6.0

# %% [markdown]
# ### 7

# %%
s = input()
print(s[4], s[8])

# %% [markdown]
# ### 8

# %%
name = input("Tên chủ hộ: ")
a = int(input("Chỉ số tháng trước: "))
b = int(input("Chỉ số tháng này: "))
x = b-a
y = x*1984+max(0,x-50)*66+max(0,x-100)*330+max(0,x-200)*618+max(0,x-300)*352+max(0,x-400)*110
print("Họ và tên:", name)
print("Tiền phải trả là:", int((y*1.08)))
# Out:
# Họ và tên: a
# Tiền phải trả là: 107136

# %% [markdown]
# ### 1

# %%
print(int(input())%2==0)

# %% [markdown]
# ### 2

# %%
print(int(input()%10==5))

# %% [markdown]
# ### 3

# %%
print(int(input()%15==0))

# %% [markdown]
# ### 4

# %%
print((2026-int(input())) >= 18)

# %% [markdown]
# ### 5

# %%
a,b = map(int, input().split())
if a == b:
    print("Hai số bằng nhau")
else:
    print(max(a,b))

# %% [markdown]
# ### 6

# %%
n = input()
if n.isdigit():
    print(f"{n} là số")
else:
    print(f"{n} là chữ")

# %% [markdown]
# ### 7

# %%
if float(input()) >= 8.0:
    print("Giỏi")
elif float(input()) >= 6.5:
    print("Khá")
elif float(input()) >= 5.0:
    print("Trung bình")
else:
    print("Yếu")

# %% [markdown]
# ### 8

# %%
print(int(input()) % 4 == 0 and int(input()) % 100 != 0 or int(input()) % 400 == 0)
# Out:
# True

# %% [markdown]
# ### 9

# %%
if int(input()) == 0:
    print("Không")
elif int(input()) == 1:
    print("Một")
elif int(input()) == 2:
    print("Hai")
elif int(input()) == 3:
    print("Ba")
elif int(input()) == 4:
    print("Bốn")
elif int(input()) == 5:
    print("Năm")
elif int(input()) == 6:
    print("Sáu")
elif int(input()) == 7:
    print("Bảy")
elif int(input()) == 8:
    print("Tám")
elif int(input()) == 9:
    print("Chín")

# %% [markdown]
# ### 10

# %%
if float(input()) >= 4.0:
    print("Qua môn")
else:
    print("Học lại")

# %% [markdown]
# ### 11

# %%
print(2025-int(input()))
print(2025-int(input()) >= 18)
